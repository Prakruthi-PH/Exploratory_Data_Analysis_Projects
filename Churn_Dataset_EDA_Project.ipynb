# %% [markdown]
# # **Exploratory Data Analysis of Telecom Customer Churn**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The telecom industry experiences **high customer churn**, making it crucial to understand why **customers leave**. This **EDA** aims to identify key patterns, trends, and factors influencing **churn** by analyzing **customer demographics**, **services**, **billing details**, and account information. The goal is to uncover actionable **insights** that help improve customer **retentio**n and support future **churn prediction** models.

# %% [markdown]
# # **Objectives**
# - Identify the overall **churn rate** and compare it with **active customers**.
#
# - Analyze key features such as **demographics**, **services**, **billing**, and account details that influence **customer churn.**
#
# - Uncover important **patterns**, **correlations**, and **trends** using EDA.
#
# - Provide **actionable insight**s to improve **customer retention** strategies.

# %% [markdown]
# ##**Import libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Load data**

# %%
data = pd.read_csv('/content/telecom_churn_data.csv')
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ## **Data Description**
# The dataset contains **customer information** from a telecom company, including demographics, service subscriptions, account details, billing information, and a **churn flag** indicating whether a customer has left the service. It helps analyze **customer behavior** and identify key factors contributing to **customer churn**.
#
# **customerID** – Unique identifier assigned to each customer.
#
# **gender** – Customer’s gender (Male/Female).
#
# **SeniorCitizen** – Indicates if the customer is a senior citizen (0 = No, 1 = Yes).
#
# **Partner** – Whether the customer has a partner (Yes/No).
#
# **Dependents** – Whether the customer has dependents (Yes/No).
#
# **tenure** – Number of months the customer has stayed with the company.
#
# **PhoneService** – Indicates if the customer has phone service (Yes/No).
#
# **MultipleLines** – Availability of multiple phone lines.
#
# **InternetService** – Type of internet service (DSL/Fiber optic/No).
#
# **OnlineSecurity** – Online security service status.
#
# **OnlineBackup** – Online backup service status.
#
# **DeviceProtection** – Device protection plan status.
#
# **TechSupport** – Technical support service status.
#
# **StreamingTV** – Access to streaming TV service.
#
# **StreamingMovies** – Access to streaming movie service.
#
# **Contract** – Customer’s contract type (Month-to-month/One year/Two year).
#
# **PaperlessBilling** – Indicates if customer uses paperless billing (Yes/No).
#
# **PaymentMethod** – Customer’s mode of payment.
#
# **MonthlyCharges** – Monthly charges billed to the customer.
#
# **TotalCharges** – Total charges incurred by the customer.
#
# **Churn** – Indicates whether the customer has discontinued the service (Yes/No).

# %% [markdown]
# ## **Basic Checks**

# %%
# number of rows and columns
data.shape
# Out:
# (7043, 21)

# %% [markdown]
# Clearly shows there are **7043 rows** and **21 columns**.

# %%
# print first 5 rows
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# print last 5 rows
data.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
# check info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7038 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# check data types
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# In this data data type of **TotalCharges** is object even though it has float value. Incorrect data type which we need to correct.

# %%
# print all columns
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# print all the numeric columns
num_data = data.select_dtypes(include=['int64','float64'])
num_data
# Out:
#       SeniorCitizen  tenure  MonthlyCharges
# 0                 0       1           29.85
# 1                 0      34           56.95
# 2                 0       2           53.85
# 3                 0      45           42.30
# 4                 0       2           70.70
# ...             ...     ...             ...
# 7038              0      24           84.80
# 7039              0      72          103.20
# 7040              0      11           29.60
# 7041              1       4           74.40
# 7042              0      66          105.65
#
# [7043 rows x 3 columns]

# %%
# print all categorical columns
cat_data = data.select_dtypes(include='object')
cat_data
# Out:
#       customerID  gender Partner Dependents PhoneService     MultipleLines  \
# 0     7590-VHVEG  Female     Yes         No           No  No phone service
# 1     5575-GNVDE    Male      No         No          Yes                No
# 2     3668-QPYBK    Male      No         No          Yes                No
# 3     7795-CFOCW    Male      No         No           No  No phone service
# 4     9237-HQITU  Female      No         No          Yes                No
# ...          ...     ...     ...        ...          ...               ...
# 7038  6840-RESVB    Male     Yes        Yes          Yes               Yes
# 7039  2234-XADUH  Female     Yes        Yes          Yes               Yes
# 7040  4801-JZAZL  Female     Yes        Yes           No  No phone service
# 7041  8361-LTMKD    Male     Yes         No          Yes               Yes
# 7042  3186-AJIEK    Male      No         No          Yes                No
#
# ...

# %%
# statistical report of numerical data
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7041.000000
# mean        0.162147    32.371149       64.749581
# std         0.368612    24.559481       30.085731
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# statistical report of categorical data
data.describe(include='object')
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7038    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     3186-AJIEK   Male      No         No          Yes            No
# freq             1   3550    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
# find unique values
df =data[['gender', 'Partner', 'Dependents', 'PhoneService',
       'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
       'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
       'Contract', 'PaperlessBilling', 'PaymentMethod',
       'Churn']]
for x in df:
  print(f"{x}-->{df[x].unique()}")
  print()
# Out:
# gender-->['Female' 'Male' nan]
#
# Partner-->['Yes' 'No']
#
# Dependents-->['No' 'Yes']
#
# PhoneService-->['No' 'Yes']
#
# MultipleLines-->['No phone service' 'No' 'Yes']
#
# InternetService-->['DSL' 'Fiber optic' 'No']
#
# OnlineSecurity-->['No' 'Yes' 'No internet service']
#
# OnlineBackup-->['Yes' 'No' 'No internet service']
#
# DeviceProtection-->['No' 'Yes' 'No internet service']
#
# TechSupport-->['No' 'Yes' 'No internet service']
#
# StreamingTV-->['No' 'Yes' 'No internet service']
#
# StreamingMovies-->['No' 'Yes' 'No internet service']
#
# Contract-->['Month-to-month' 'One year' 'Two year']
#
# PaperlessBilling-->['Yes' 'No' nan]
#
# PaymentMethod-->['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
#
# Churn-->['No' 'Yes']

# %%
# find value counts
for x in df:
  print(df[x].value_counts())
  print()
# Out:
# gender
# Male      3550
# Female    3488
# Name: count, dtype: int64
#
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
#
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
#
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
#
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64
#
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
#
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64
#
# OnlineBackup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64
#
# DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64
#
# TechSupport
# No                     3473
# ...

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# **Find duplicates**

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There are **no duplicates** in dataset.

# %% [markdown]
# **Find Missing values**

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              5
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    2
# PaymentMethod       0
# MonthlyCharges      2
# TotalCharges        5
# Churn               0
# dtype: int64

# %% [markdown]
# There are **missing values** in **gender** , **PaperlessBilling** , **MonthlyCharges**	, **TotalCharges** which needs to be handled.

# %% [markdown]
# ### **How to Handle Missing Values**

# %% [markdown]
# **gender**

# %%
# check data type
data.loc[:,'gender'].dtype
# Out:
# dtype('O')

# %%
# since data type of gender is object, we need to replace with mode
# find mode
data.loc[:,'gender'].mode()[0]
# Out:
# 'Male'

# %%
# fill with mode
data.loc[:,'gender'] = data.loc[:,'gender'].fillna(data.loc[:,'gender'].mode()[0])

# %%
# check missing
data.loc[:,'gender'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **PaperlessBilling**

# %%
# check the data type
data.loc[:,'PaperlessBilling'].dtype
# Out:
# dtype('O')

# %%
# since data type of PaperlessBilling is object, we need to replace with mode
# find mode
data.loc[:,'PaperlessBilling'].mode()[0]
# Out:
# 'Yes'

# %%
# fill with mode
data.loc[:,'PaperlessBilling']=data.loc[:,'PaperlessBilling'].fillna(data.loc[:,'PaperlessBilling'].mode()[0])

# %%
# check null
data.loc[:,'PaperlessBilling'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **MonthlyCharges**

# %%
# check the data type
data.loc[:,'MonthlyCharges'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# Data type of **MonthlyCharges** is numerical.

# %%
# check the distribution of MonthlyCharges
plt.figure(figsize=(5,2))
sns.histplot(data,x='MonthlyCharges',kde=True)
plt.show()

# %% [markdown]
# 1. If **skewness** value is within **[-0.5,0.5]**--> **normal distribution** --> replace with **mean**
# 2. If **skewness** is **greater than 0.5** --> **right skewed** --> replace with **median**
# 3. If **skewness** is **less than -0.5** --> **left skewed** --> replace with **median**

# %%
# find skewness
data.loc[:,'MonthlyCharges'].skew()
# Out:
# np.float64(-0.22028439456532767)

# %% [markdown]
# Clearly skewness of **MonthlyCharges** is **-0.2** which is within **[-0.5 , 0.5]**.Hence the distribution of **MonthlyCharges** is **normal distribution** so we replace **missing values** with **mean**.

# %%
# find mean
data.loc[:,'MonthlyCharges'].mean()
# Out:
# np.float64(64.74958102542253)

# %%
# fill with mean
data.loc[:,'MonthlyCharges'] = data.loc[:,'MonthlyCharges'].fillna(data.loc[:,'MonthlyCharges'].mean())

# %%
# check null
data.loc[:,'MonthlyCharges'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **TotalCharges**

# %%
# check data type
data.loc[:,'TotalCharges'].dtype
# Out:
# dtype('O')

# %% [markdown]
# Convert **data type** of **TotalCharges** which is an **object data type** into **float64**, because values within TotalCharges are **float**.
#
# 1. **astype** : Used to convert one data type into other if column has **no missing values**.
# 2. **pd.to_numeric** : Used to convert data type of column into other data type  when **there are missing values** in data

# %%
data.loc[:,'Total_Charges'] = pd.to_numeric(data.loc[:,'TotalCharges'],errors='coerce')
# error=coerce convert empty string into nan

# %%
# check data type
data.loc[:,'Total_Charges'].dtype
# Out:
# dtype('float64')

# %%
# drop the old column
data.drop(columns='TotalCharges',inplace=True)

# %%
# check distribution
plt.figure(figsize=(5,2))
sns.histplot(data,x='Total_Charges',kde=True)
plt.show()

# %%
# find skew
data.loc[:,'Total_Charges'].skew()
# Out:
# np.float64(0.9616058347613503)

# %% [markdown]
# Since skewnes sis 0.95 which is greater than 0.5. hence distribution is right skewed.

# %%
# find median
data.loc[:,'Total_Charges'].median()
# Out:
# 1397.3

# %%
data.loc[:,'Total_Charges']=data.loc[:,'Total_Charges'].fillna(data.loc[:,'Total_Charges'].median())

# %%
#check null
data.loc[:,'Total_Charges'].isnull().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# Churn               0
# Total_Charges       0
# dtype: int64

# %% [markdown]
# ## **Explore data using Visualization**

# %% [markdown]
# **What is the count of customer churn?**

# %%
plt.figure(figsize=(5,2))
sns.countplot(data,x='Churn',hue='Churn',palette='rainbow')
plt.show()

# %% [markdown]
# **Insights**
# 1. **Customer retension**: A large proportion of customer are continuing the service indicates that, customers are happy with service.
# 2. **Customer churn** : A significant amount of customer churn the service indicates that company should work identifying the issue and resolving them.
# 3. Overall most of the customers are happy with service but few had left service. COmpany should work on addressing the issues to reduce churn rate .

# %% [markdown]
# **Find percentage of customers who are leaving service**

# %%
plt.figure(figsize=(3,3))
data.loc[:,'Churn'].value_counts().plot.pie(autopct='%1.2f%%')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Insights**
# 1. Approximately  73.46% of customers are continuing the service indicates that the customers are  happy with service.
# 2. Nearly 26.54% customers have left the service indicates the company should work work imoproving the their service to reduce churn rate.

# %% [markdown]
# **What is the proportion of customers using different Internet Services**

# %%
plt.figure(figsize=(3,3))
data.loc[:,'InternetService'].value_counts().plot.pie(autopct='%1.2f%%',colormap='Pastel2')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Insights**
# 1. Almost 44% of the customers are using fibre optic indicates that it has more demand among the services.
# 2. Nearly 34.37% of customers are using DSL.
# 3. About 21.67% of the customers are not using any internet service.
# 4. Since fibre optic has huge demand this factor would help us in understanding the reason for churn.

# %% [markdown]
# **What percentage of customers using different payment method**

# %%
plt.figure(figsize=(3,3))
data.loc[:,'PaymentMethod'].value_counts().plot.pie(autopct='%1.2f%%',colormap='Set1')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Insights**
# 1. Most of the customers around 33.58% using electronic check which is manual payment method
# 2. Nearly 22.89% customers using Mailed check.
# 3. 21.61% customers using credit card
# 4. 21.92% customers are are using bank transfer.
# 5. Payment method is also important factor to bve considered to understand churn rate.

# %% [markdown]
# **What percentage of male and female customers**

# %%
plt.figure(figsize=(3,3))
data.loc[:,'gender'].value_counts().plot.pie(autopct='%1.2f%%',colormap='tab10')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Insights**
#
# We have equal proportion of male and female customers.

# %% [markdown]
# **What percentage of customers using different contract type**

# %%
plt.figure(figsize=(3,3))
data.loc[:,'Contract'].value_counts().plot.pie(autopct='%1.2f%%',colormap='tab10')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Insights**
# 1. Approximately 55% of the customers using month to month.
# 2. nearly 20.9% of the customers using one year plan and followed by 24.07% of the customers using Two year plan.
# 3. Since maximum customers opting for month-to-month service indicates lower commitment with service which might lead to high churn rate.
# 4. Company should focus on converting short term plan customers to long term plan with offers or discounts or with good support.

# %% [markdown]
# **What percentage of people getting TechSupport**

# %%
plt.figure(figsize=(3,3))
data.loc[:,'TechSupport'].value_counts().plot.pie(autopct='%1.2f%%',colormap='Set3')
plt.ylabel('')
plt.show()

# %% [markdown]
# **Insights**
# 1. Majority of the customer nearly 50% of the customers not getting proper technical support which might lead to high churn rate.
# 2. Nearly 29% of the customers are getting technical support which is too less.
# 3. Technical support should be improved so that we can reduce the churn rate.

# %% [markdown]
# **How customers among male and female are likely to churn**

# %%
plt.figure(figsize=(5,2))
sns.countplot(data,x='gender',hue='Churn',palette='rainbow')
plt.show()

# %% [markdown]
# **Insights**
# 1. We have equal proportion of male and female customers.
# 2. It clearly shows equal proportion of churn among male and female.
# 3. Gender is not a factor which influence the churn.

# %% [markdown]
# **How many Customers using Different Internet Services are more likely churn**

# %%
plt.figure(figsize=(7,2))
sns.countplot(data,x='InternetService',hue='Churn',palette='viridis')
plt.show()

# %% [markdown]
# **Insights**
# 1. Customer churn is very high among customers who have opted for fibre optic.
# 2. Customers churn is less with DSL and with customers who doen't have internet service.
# 3. Despite having huge demand for fibre optic the churn rate is very high so company should work enhancing the quality and service  so churn can be reduced.

# %% [markdown]
# **How many customers are more likely to churn with TechSupport**

# %%
plt.figure(figsize=(7,2))
sns.countplot(data,x='TechSupport',hue='Churn',palette='pastel')
plt.show()

# %% [markdown]
# **Insights**
# 1. Maximum customers not getting proper tech support and churn rate is very high among them.
# 2. Customers with tech support and no internet serviuces are less likely to churn.
# 3. Lack of tech support resulting in high churn rate company should work on enhancing tech support to provide accurate resolutions to customer queries so we can reduce churn rate.

# %% [markdown]
# **How many customers are likely to churn with different contract types**

# %%
plt.figure(figsize=(7,2))
sns.countplot(data,x='Contract',hue='Churn',palette='pastel')
plt.show()

# %% [markdown]
# **Insights**
# * Customers who opted month-to-month service are more likely to churn because they are testing the service.
# * Customers with one year and two year plan are less likely to churn.
# * Company should encourage customers to convert their plan for full time by providing best service , offers or discount.

# %% [markdown]
# **How many customers are more likely to churn with different payment methods**

# %%
plt.figure(figsize=(7,2))
sns.countplot(data,x='PaymentMethod',hue='Churn',palette='dark')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insights**
# 1. Customers using Electronic check are more likely to churn because its a manual payment.
# 2. Customers using automatic payment methods like Bank transfer or credit card the chance of churn is very less.
# 3. Encourage customers to use automatic payments rather than using manual payment methods  so that churn can be reduced.

# %% [markdown]
# **Will customers with dependents are more likely to churn**

# %%
plt.figure(figsize=(7,2))
sns.countplot(data,x='Dependents',hue='Churn',palette='bright')
plt.show()

# %% [markdown]
# **Insights**
#
# Customers with no dependents are more likely to churn compare to customer with dependents.

# %% [markdown]
# **Will churn be high with SeniorCitizen**

# %%
plt.figure(figsize=(7,2))
sns.countplot(data,x='SeniorCitizen',hue='Churn',palette='bright6')
plt.show()

# %% [markdown]
# **Insights**
#
# * Customer churn rate is high among senior citizen compared to youths.
# * Comapany should offer quality service proper tech support better offers would help in reducing the churn.

# %% [markdown]
# **Will churn be high with StreamingTV**

# %%
plt.figure(figsize=(7,2))
sns.countplot(data,x='StreamingTV',hue='Churn',palette='deep6')
plt.show()

# %% [markdown]
# **Insights**
# Customers without streaming service are more likely to churn compared to customers with streaming service.

# %% [markdown]
# **Will churn be high with StreamingMovies**

# %%
plt.figure(figsize=(7,2))
sns.countplot(data,x='StreamingMovies',hue='Churn',palette='viridis')
plt.show()

# %% [markdown]
# **Insights**
#
# Customer churn rate is high with customers having no streaming movies compared to customers with streaming movies.

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'Churn', 'Total_Charges'],
#       dtype='object')

# %% [markdown]
# **What is the distribution of Monthy Charges**

# %%
plt.figure(figsize=(5,2))
sns.histplot(data,x='MonthlyCharges',kde=True,color='orange')
plt.show()

# %% [markdown]
# **Insights**
# * Maximum  customers are paying monthly charges around 70 to 100.
# * Very few customers paying less and high monthly charges.
# * Distribution is normal.

# %% [markdown]
# **Distribution of Monthly charges with churn**

# %%
plt.figure(figsize=(5,2))
sns.histplot(data,x='MonthlyCharges',kde=True,hue='Churn')
plt.show()

# %% [markdown]
# **What is the distribution of Total_Charges**

# %%
plt.figure(figsize=(5,2))
sns.histplot(data,x='Total_Charges',kde=True,color='yellow')
plt.show()

# %% [markdown]
# **What is the distribution of tenure**

# %%
plt.figure(figsize=(5,2))
sns.histplot(data,x='tenure',kde=True,color='pink')
plt.show()

# %% [markdown]
# **Will average monthly charges impact a churn**

# %%
plt.figure(figsize=(5,2))
sns.barplot(data,x='Churn',y='MonthlyCharges',hue='Churn',palette='Set1')
plt.show()

# %% [markdown]
# **Insights**
# 1. Clearly indicates that churn rate is high among customers who are paying high monthly charges.
# 2. Customers churn rate is less among people who are paying less monthly charges.
# 3. Company should revise monthly charges so churn can be reduced.

# %% [markdown]
# **Will tenure impact a churn**

# %%
plt.figure(figsize=(5,2))
sns.barplot(data,x='Churn',y='tenure',hue='Churn',palette='Set1')
plt.show()

# %% [markdown]
# **Insights**
# 1. Customers with high tenure are less likely to churn.
# 2. Customer churn rate is high with customers who are using service for less tenure.
# 3. Company should be little cautious of customers who opted service for less tenure by provide quality service, enhancing tech suppot and providing offers and  discounts

# %% [markdown]
# **Will Total_Charges impact a churn**

# %%
plt.figure(figsize=(5,2))
sns.barplot(data,x='Churn',y='Total_Charges',hue='Churn',palette='Set1')
plt.show()

# %% [markdown]
# **Insights**
# 1. Customers paying high total charges are less likely to churn compared to people who pay less total charges.

# %% [markdown]
# **How month charges with contract type will impact a churn**

# %%
plt.figure(figsize=(7,3))
sns.barplot(data,x='Contract',y='MonthlyCharges',hue='Churn',palette='Set1')
plt.show()

# %% [markdown]
# **Insights**
# 1. Customers using month-to-month service who are paying high monthly charges are more likely to churn.
# 2. Even with people using one year plan , two year pal are also more likely to churn if monthly charges are high.

# %% [markdown]
# **How TechSupport and total charges  impact on churn**

# %%
plt.figure(figsize=(7,3))
sns.barplot(data,x='TechSupport',y='Total_Charges',hue='Churn',palette='Set2')
plt.show()

# %% [markdown]
# **Insights**
# 1. Customers without tech support are more likely to churn.

# %% [markdown]
# **How Internet Service and Total Charges impact Churn**

# %%
plt.figure(figsize=(7,3))
sns.barplot(data,x='InternetService',y='Total_Charges',hue='Churn',palette='Set3')
plt.show()

# %% [markdown]
# **Insights**
#
# Customers opting fibre optic with less total charge might lead to churn.

# %% [markdown]
# **Are there outliers in Monthly charges**

# %%
plt.figure(figsize=(5,2))
sns.boxplot(data,x='MonthlyCharges',color='red')
plt.show()

# %% [markdown]
# **Are there outliers in Totalcharges**

# %%
plt.figure(figsize=(5,2))
sns.boxplot(data,x='Total_Charges',color='pink')
plt.show()

# %% [markdown]
# **Are there outliers in tenure**

# %%
plt.figure(figsize=(5,2))
sns.boxplot(data,x='tenure',color='cyan')
plt.show()

# %% [markdown]
# **How do InternetService and TechSupport combined affect Churn?**

# %%
df = pd.crosstab([data['InternetService'],data['TechSupport']],data['Churn'])
df
# Out:
# Churn                                  No   Yes
# InternetService TechSupport
# DSL             No                    898   345
#                 Yes                  1064   114
# Fiber optic     No                   1129  1101
#                 Yes                   670   196
# No              No internet service  1413   113

# %%
df.plot(kind='barh',figsize=(5,3))
plt.show()

# %% [markdown]
# **Insights**
# * Customers with Fibre option and no tech support the chance of churn is very high.
#
# * Customers using DSL and no tech support will have high chance of churn.,
#
# * Tech support is important.

# %%
df.plot(kind='barh',figsize=(5,3),stacked=True)
plt.show()

# %% [markdown]
# **How TechSupport,Contract impact Churn**

# %%
df = pd.crosstab([data['TechSupport'],data['Contract']],data['Churn'])
df
# Out:
# Churn                                 No   Yes
# TechSupport         Contract
# No                  Month-to-month  1330  1350
#                     One year         475    82
#                     Two year         222    14
# No internet service Month-to-month   425    99
#                     One year         355     9
#                     Two year         633     5
# Yes                 Month-to-month   465   206
#                     One year         477    75
#                     Two year         792    29

# %%
df.plot(kind='barh',figsize=(5,3))
plt.show()

# %% [markdown]
# **Insights**
# Customers using month-to-month service with no tech support are more likely to churn.

# %%
df.plot(kind='barh',figsize=(5,3),stacked=True)
plt.show()

# %% [markdown]
# # **Overall Conclusion**
#
# - **Churn rate** is around 26%, which is moderate but concerning.
#
# - **Month-to-month contracts** show the highest churn.
#
# - Customers paying **higher monthly charges** are more likely to leave.
#
# - **Fiber optic** users have higher churn despite contributing higher revenue.
#
# - Customers without **tech support** churn more.
#
# - **Automatic payment** users churn less.
#
# - Demographics like gender have minimal impact.
#
# - Customers with long-term contracts and added services stay longer and generate higher total revenue.
#
# 👉 Churn is mainly driven by price sensitivity, short-term contracts, and lack of value-added services, not demographics.

# %% [markdown]
# # **Key Recommendations**
# 1️⃣ **Promote Long-Term Contracts**
#
# Offer discounts, loyalty rewards, or bundled benefits to move customers from month-to-month to annual plans.
#
# 2️⃣ Improve Value for **High-Paying Customers**
#
# Enhance service quality, speed, and support for fiber and high-charge customers to reduce dissatisfaction.
#
# 3️⃣ Encourage **Automatic Payments**
#
# Provide incentives for switching to auto-pay methods to improve retention.
#
# 4️⃣ Bundle **Tech Support**
#
# Promote tech support packages to increase engagement and reduce churn risk.
#
# 5️⃣ Focus on **Early Retention**
#
# Improve onboarding experience and engagement in the first few months to prevent early churn.
